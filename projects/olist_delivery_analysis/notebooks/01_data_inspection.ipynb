# %% [markdown]
# # 01 - Olist Orders Data Inspection
#
# This notebook loads the raw orders table and performs four basic checks before cleaning or analysis.

# %%
from pathlib import Path
import pandas as pd

# %%
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
data_file = project_root / 'data' / 'raw' / 'olist_orders_dataset.csv'
orders = pd.read_csv(data_file)

# %% [markdown]
# ## Shape
# The two values represent `(rows, columns)`.

# %%
orders.shape

# %% [markdown]
# ## First five rows

# %%
orders.head()

# %% [markdown]
# ## Column data types

# %%
orders.dtypes

# %% [markdown]
# ## Missing values by column

# %%
orders.isna().sum()

# %% [markdown]
# ## Initial observations
#
# - The orders table contains 99,441 rows and 8 columns.
# - The timestamp columns are initially loaded as `object` and will need datetime conversion.
# - Missing values appear in approval, carrier-delivery, and customer-delivery timestamps.
# - No rows are removed at this inspection stage.
